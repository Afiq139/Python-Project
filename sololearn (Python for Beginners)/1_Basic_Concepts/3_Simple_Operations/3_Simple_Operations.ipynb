# %% [markdown]
# What does this code output?

# %%
print(1+2+3)
# Out:
# 6

# %% [markdown]
# Which option is the output of this code?
#
# 6, 6.0, 8

# %%
print((4+8)/2)
# Out:
# 6.0

# %%
print((4+8)//2)
# Out:
# 6
