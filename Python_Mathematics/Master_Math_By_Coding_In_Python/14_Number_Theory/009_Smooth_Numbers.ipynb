# %% [markdown]
# # 009 Smooth numbers

# %%
import numpy as np 
import sympy as sym 
import matplotlib.pyplot as plt

# %%
maxN = 10000

largestPrimeFact = np.zeros(maxN+1, dtype=int)/0

for i in range(2,maxN+1):
    largestPrimeFact[i] = np.max(sym.primefactors(i))

# largestPrimeFact

plt.plot(largestPrimeFact,'k.', markersize=.5)
plt.xlabel('Number')
plt.ylabel('Largest Prime Factor')

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_22960\1533237751.py:3: RuntimeWarning: invalid value encountered in divide
#   largestPrimeFact = np.zeros(maxN+1, dtype=int)/0
