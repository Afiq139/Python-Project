# %% [markdown]
# # 003 Euclid's Pythagorean triplets

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
numberrange = np.arange(2,51)

a = []
b = []
c = []

for m in numberrange:
    for n in numberrange:
        a.append( m**2 - n**2)
        b.append(2*m*n)
        c.append(m**2 + n**2)

# %%
fig,ax = plt.subplots(1,figsize=(10,7))

plt.scatter(a,b,c=c, marker='o', alpha=.5,linewidth=.5,edgecolors='k')
# plt.axis('off')
plt.show()

# %% [markdown]
# # Exercise

# %%
x = []
y = []
z = []

for i in numberrange:
    for k in range(numberrange[0], i):
        x.append( i**2 - k**2)
        y.append(2*i*k)
        z.append(i**2 + k**2)

# %%
fig,ax = plt.subplots(1,figsize=(10,7))

plt.scatter(x,y,c=z, marker='o', alpha=.5,linewidth=.5,edgecolors='k')
#plt.axis('off')
plt.show()

# %%
pythcheck = np.array(a)**2 + np.array(b)**2 - np.array(c)**2

plt.plot(pythcheck,'o')
plt.show()

# %%
np.array([2,3])**2
# Out:
# array([4, 9])
