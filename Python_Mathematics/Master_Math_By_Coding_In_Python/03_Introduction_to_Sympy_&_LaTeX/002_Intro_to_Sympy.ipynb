# %% [markdown]
# # 002 Intro to Sympy Part 1

# %%
import sympy as sym
import numpy as np
sym.init_printing()
from IPython.display import display

# %%
x, y = sym.symbols('x,y')
x
# Out:
# x

# %%
y + 4  #sym.init_printing()
# Out:
# y + 4

# %%
display(x**y)
display(x/y)
# Out:
#  y
# x
# x
# ─
# y

# %%
display(np.sqrt(2)) #estimate or computation of sqrt of 2
display(sym.sqrt(2)) #symbol for sqrt of 2
# Out:
# 1.4142135623730951
# √2

# %% [markdown]
# # Exercises

# %%
# 1.)
display(y*x**2)
# Out:
#  2
# x ⋅y

# %%
# 2.)
display(sym.sqrt(4)*x)
# Out:
# 2⋅x

# %%
#3.)
display(sym.sqrt(x)*sym.sqrt(x))
# Out:
# x

# %%
# need to use Latex coding
#next
