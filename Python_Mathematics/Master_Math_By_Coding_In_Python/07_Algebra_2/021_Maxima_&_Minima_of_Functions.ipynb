# %% [markdown]
# # 021 Maxima and Minima of functions

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lst = [-4,5.5,1,2]

maxval = np.min(lst) # minimum number
maxvalidx = np.argmax(lst) # index of the number

lst[maxvalidx]
# Out:
# 5.5

# %%
x = np.linspace(0, 2*np.pi, 20)
fx = -(np.cos(x) + np.sqrt(x))

fmax = np.max(fx)
fmaxidx = np.argmax(fx)
print(fmax, fmaxidx)

plt.plot(x,fx, 'bo-')
plt.plot(x[fmaxidx],fmax,'rs')

plt.show()
# Out:
# -0.7388185920927908 9

# %%
x = np.linspace(-2,2,51)

fx = x**3 + x**4
fminidx = np.argmin(fx)

plt.plot(x,fx,'bs-')
plt.plot(x[fminidx], fx[fminidx], 'rs')

plt.xlim([-1.2,.5])
plt.ylim([-.12,-.1])
plt.show()
