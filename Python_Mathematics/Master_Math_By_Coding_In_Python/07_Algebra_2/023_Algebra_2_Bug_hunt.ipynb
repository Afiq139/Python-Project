# %% [markdown]
# # 023 Algebra 2 Bug Hunt!

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
from IPython.display import display, Math

# %%
# 1.) create a list
lst = [1,3,4,1,6]

print(lst)
# Out:
# [1, 3, 4, 1, 6]

# %%
# 2.) add all the numbers together
print(np.sum(lst))
# Out:
# 15

# %%
# 3.) Plot the cumulative sum of a list of numbers

l = np.arange(-4,10)

plt.plot(l,'rs-')
plt.plot(np.cumsum(l), 'bo-')
plt.legend({'list', 'cumsum'})
plt.show()

# %%
# 4.) 

### the equation:
# 4 -2x + 0x^2 + 5x^3

# define the coefficients
coefs = [5,0,-2,4]

# solve
roots = np.roots(coefs)

# and display
from sympy.abc import x

p = sym.Poly(coefs,x)

display(Math(sym.latex(p)))
# Out:
# $\displaystyle \operatorname{Poly}{\left( 5 x^{3} - 2 x + 4, x, domain=\mathbb{Z} \right)}$
