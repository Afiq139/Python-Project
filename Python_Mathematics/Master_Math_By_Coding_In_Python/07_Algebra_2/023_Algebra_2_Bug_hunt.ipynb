# %% [markdown]
# # 023 Algebra 2 Bug Hunt!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1.) create a list
lst = [1,3,4,1,6]

print(lst)
# Out:
# [1, 3, 4, 1, 6]

# %%
# 2.) add all the numbers together
print(np.sum(lst))
# Out:
# 15
