# %% [markdown]
# # 013 Finding Critical Points Exercise

# %%
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math

# %%
a,x = sym.symbols('a,x')

baseexpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2.25,.25)
xrange = np.linspace(-3,3,100)

# setup the figure
fig, ax = plt.subplots(1,2)

for ai in arange:
    fx = baseexpr.subs(a,ai)
    dfx = sym.diff(fx)
    critpnts = sym.solve(dfx)
    # print(critpnts)

    #plotting
    ax[0].plot(xrange,sym.lambdify(x,fx)(xrange))
    ax[1].plot(xrange,sym.lambdify(x,dfx)(xrange))

    #test for the critical points
    # print(critpnts)
    if 1 in critpnts:
        display(Math('\\Rightarrow %s \\text{ has a critical point at x=1 !! }' %sym.latex(fx)))
    elif 2 in critpnts:
        display(Math('\\Rightarrow %s \\text{ has a critical point at x=2 !! }' %sym.latex(fx)))
    else:
        display(Math('\\Rightarrow %s \\text{ has NO critical points at x=1 or x=2 }' %sym.latex(fx)))

ax[0].set_ylim([0,2])
ax[0].set_title('Function')
ax[0].plot([1,1],[0,2],'--',color='gray')
ax[0].plot([2,2],[0,2],'--',color='gray')

ax[1].set_ylim([-2,2])
ax[1].set_title('Its derivative')
ax[1].plot([1,1],[-2,2],'--',color='gray')
ax[1].plot([2,2],[-2,2],'--',color='gray')

plt.show()
# Out:
# $\displaystyle \Rightarrow x^{2} \text{ has NO critical points at x=1 or x=2 }$
# $\displaystyle \Rightarrow x^{2} e^{- 0.25 x^{2}} \text{ has a critical point at x=2 !! }$
# $\displaystyle \Rightarrow x^{2} e^{- 0.5 x^{2}} \text{ has NO critical points at x=1 or x=2 }$
# $\displaystyle \Rightarrow x^{2} e^{- 0.75 x^{2}} \text{ has NO critical points at x=1 or x=2 }$
# $\displaystyle \Rightarrow x^{2} e^{- 1.0 x^{2}} \text{ has a critical point at x=1 !! }$
# $\displaystyle \Rightarrow x^{2} e^{- 1.25 x^{2}} \text{ has NO critical points at x=1 or x=2 }$
# $\displaystyle \Rightarrow x^{2} e^{- 1.5 x^{2}} \text{ has NO critical points at x=1 or x=2 }$
# $\displaystyle \Rightarrow x^{2} e^{- 1.75 x^{2}} \text{ has NO critical points at x=1 or x=2 }$
# $\displaystyle \Rightarrow x^{2} e^{- 2.0 x^{2}} \text{ has NO critical points at x=1 or x=2 }$
