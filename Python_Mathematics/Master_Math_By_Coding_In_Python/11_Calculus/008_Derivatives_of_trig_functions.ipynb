# %% [markdown]
# # 008 Derivatives of Trig Functions

# %%
import sympy as sym
from IPython.display import display, Math
import sympy.plotting.plot as symplot

# %%
q = sym.symbols('q')

print(sym.diff(sym.cos(q)))
print(sym.diff(sym.sin(q)))
# Out:
# -sin(q)
# cos(q)

# %%
f = sym.cos(q)

for i in range(0,8):
    display(Math('\\frac{d}{dx}%s = %s' %(sym.latex(f),sym.latex(sym.diff(f)))))
    f = sym.diff(f)
# Out:
# $\displaystyle \frac{d}{dx}\cos{\left(q \right)} = - \sin{\left(q \right)}$
# $\displaystyle \frac{d}{dx}- \sin{\left(q \right)} = - \cos{\left(q \right)}$
# $\displaystyle \frac{d}{dx}- \cos{\left(q \right)} = \sin{\left(q \right)}$
# $\displaystyle \frac{d}{dx}\sin{\left(q \right)} = \cos{\left(q \right)}$
# $\displaystyle \frac{d}{dx}\cos{\left(q \right)} = - \sin{\left(q \right)}$
# $\displaystyle \frac{d}{dx}- \sin{\left(q \right)} = - \cos{\left(q \right)}$
# $\displaystyle \frac{d}{dx}- \cos{\left(q \right)} = \sin{\left(q \right)}$
# $\displaystyle \frac{d}{dx}\sin{\left(q \right)} = \cos{\left(q \right)}$

# %%
f = sym.cos(q)

clrs = 'krbg'

for i in range(0,4):
    if i==0:
        p = symplot(f,show=False,label= '$%s$'%sym.latex(f), line_color=(i/5,i/3,i/5))
    
    else:
        p.extend(symplot(f,show=False,label='$%s$'%sym.latex(f), line_color=(i/5,i/3,i/5) ))
        
    f = sym.diff(f)

p.legend = True
p.xlim = [-3,3]
p.show()
