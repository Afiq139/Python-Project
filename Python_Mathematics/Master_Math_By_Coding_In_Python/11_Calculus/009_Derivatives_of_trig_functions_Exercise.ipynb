# %% [markdown]
# # 009 Derivatives of Trig Functions Exercise

# %%
import sympy as sym
from IPython.display import display, Math
import sympy.plotting.plot as symplot

# %%
x,a = sym.symbols('x,a')

f = sym.cos( x + sym.sin(x) ) + a

colors = 'brkm'

for ai in range(0,4):
    if ai == 0:
        p = symplot(f.subs(a,ai), show=False,label='$%s$' %sym.latex(f.subs(a,ai)), line_color=colors[0])
    
    else:
        p.extend(symplot(f.subs(a,ai), show=False,label='$%s$' %sym.latex(f.subs(a,ai)), line_color=colors[ai]))

p.title = 'The functions'
p.legend = True
p.show()

# %%
for ai in range(0,4):
    if ai == 0:
        p = symplot(sym.diff(f.subs(a,ai)), show=False,label='$%s$' %sym.latex(f.subs(a,ai)), line_color=colors[0])
    
    else:
        p.extend(symplot(sym.diff(f.subs(a,ai)), show=False,label='$%s$' %sym.latex(f.subs(a,ai)), line_color=colors[ai]))

p.title = 'Their Derivatives'
p.legend = True
p.show()
