# %% [markdown]
# # 005 Exercise Virtual Weighted Dice

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 50

outcomes = np.zeros(6)

pureprobs = np.array([2,1,1,1,1,1])
pureprobs = pureprobs / np.sum(pureprobs)

for i in range(n):

    # roll a 7 sided die
    dieroll = np.random.randint(0,7)

    if dieroll == 6:
        dieroll = 0
    
    outcomes[dieroll] += 1

plt.bar(range(1,7), outcomes/n)

plt.show()
