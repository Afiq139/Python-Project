# %% [markdown]
# # 002 Introduction to random numbers

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nums = np.random.rand(1000)

nums = nums + 3

plt.plot(nums, 's')
plt.show()

plt.hist(nums)
plt.show()
