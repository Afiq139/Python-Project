# %% [markdown]
# # 007 Conic Bug Hunt!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1.) Make a gaussian
x = np.linspace(-2,2,100)

#create the gaussian
X,Y = np.meshgrid(x,x)
gauss2d = np.exp(-(X**2+Y**2))

# and plot
plt.imshow(gauss2d)
plt.axis('off')
plt.show()
