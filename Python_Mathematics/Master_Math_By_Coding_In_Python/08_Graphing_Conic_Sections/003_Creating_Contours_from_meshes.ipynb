# %% [markdown]
# # 003 Creating Contours from meshes in python

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X, Y = np.meshgrid(range(0,10), range(0,15))

plt.subplot(121)
plt.pcolormesh(X,edgecolor='k', linewidth=.1)

plt.subplot(122)
plt.pcolormesh(Y,edgecolor='k', linewidth=.1)

plt.show()

# %%
x = np.linspace(-np.pi, 2*np.pi,40)
y = np.linspace(0,4*np.pi,72)

X,Y = np.meshgrid(x,y)

Fxy = np.cos(X) + np.sin(Y)

plt.imshow(Fxy)
# plt.pcolormesh(Fxy, edgecolor='k', linewidth=.1)
plt.show()

# %% [markdown]
# # Exercise

# %%
x = np.linspace(-4,1,100) #position
X,Y = np.meshgrid(x,x)
s = 1 #change this parameter

gauss2d = np.exp( -(x**2+Y**2)/s)

plt.imshow(gauss2d)
plt.axis('off')
plt.show()
