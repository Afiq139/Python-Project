# %% [markdown]
# # 006 Logistic Map

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#%matplotlib notebook
#%matplotlib widget
# %matplotlib inline

rs = np.linspace(1,4,1000)

N = 500
x = .5+np.zeros(N)
endcap = np.arange(round(N*.9),N)

for ri in range(len(rs)):
    for n in range(N-1):
        x[n+1] = rs[ri]*x[n]*(1-x[n]) + .2*np.sin(2*np.pi*x[n])**2
    
    u = np.unique(x[endcap])
    r = rs[ri]*np.ones(len(u))
    plt.plot(r,u,'.',markersize=1, color=[(np.sin(ri/len(rs)/2)+1)/2,1-ri/len(rs),.5])


plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_19244\2383482768.py:13: RuntimeWarning: overflow encountered in scalar multiply
#   x[n+1] = rs[ri]*x[n]*(1-x[n]) + .2*np.sin(2*np.pi*x[n])**2
# C:\Users\USER\AppData\Local\Temp\ipykernel_19244\2383482768.py:13: RuntimeWarning: invalid value encountered in sin
#   x[n+1] = rs[ri]*x[n]*(1-x[n]) + .2*np.sin(2*np.pi*x[n])**2
