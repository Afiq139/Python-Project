# %% [markdown]
# # 002 Plotting Coordinates On A Plane

# %%
import matplotlib.pyplot as plt

# %%
x = 3
y = 5

plt.plot(x,y, 'ro')  # r = red, o = circle

plt.axis('square') # make it plot in square size

plt.show() #display the final version of the figure
