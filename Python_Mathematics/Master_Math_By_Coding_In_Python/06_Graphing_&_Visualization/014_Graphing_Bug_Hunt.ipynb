# %% [markdown]
# # 014 Graphing Bug Hunt

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#1
plt.plot(3,2,'ro')

#set axis limits
plt.axis('square')
plt.axis([-6,6,-6,6])
plt.show()

# %%
#2 plot a line
plt.plot([0,3], [0,5])
plt.axis('square')
plt.show()

# %%
#3 
x = range(-3,4)
y = np.zeros(len(x))

for i in range(0, len(x)):
    y[i] = 2 - x[i]**2

plt.plot(x,y,'s-')
plt.show()
